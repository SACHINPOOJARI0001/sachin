# %%
cars=['maruti','hero','verna','benz','volvo','suzuki']
print(cars)
# Out:
# ['maruti', 'hero', 'verna', 'benz', 'volvo', 'suzuki']

# %%
print(sorted(cars))
# Out:
# ['benz', 'hero', 'maruti', 'suzuki', 'verna', 'volvo']

# %%
cars.sort()
print(cars)
# Out:
# ['benz', 'hero', 'maruti', 'suzuki', 'verna', 'volvo']

# %%
cars.reverse()
print(cars)
# Out:
# ['volvo', 'verna', 'suzuki', 'maruti', 'hero', 'benz']

# %%
len(cars)
# Out:
# 6

# %%
len(cars)

print(cars)
# Out:
# ['volvo', 'verna', 'suzuki', 'maruti', 'hero', 'benz']

# %%
students = ('abc','xyz','pdf','word')
print(students)
# Out:
# ('abc', 'xyz', 'pdf', 'word')

# %%
students = ['abc','xyz','pdf','word']
print(students) #to make the slicing
# Out:
# ['abc', 'xyz', 'pdf', 'word']

# %%
print(students [0:1])
# Out:
# ('abc',)

# %%
print(students [0:1])
# Out:
# ['abc']

# %%
print(students [2:4])
# Out:
# ['pdf', 'word']
