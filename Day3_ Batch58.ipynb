# %%
#general syntax for string :


f" custom words {placeholder1} {placeholder2}

# %%
first_name = 'sachin'

last_name = 'p'

# %%
full_name = f"{first_name} {last_name}"

print(full_name)
# Out:
# sachin p

# %%
print(full_name.title())
# Out:
# Sachin P

# %%
message = f"Doing well keep it up, {first_name} {last_name}"
print(message.title())
# Out:
# Doing Well Keep It Up, Sachin P

# %%
print('favourite_programming_language:pythoncjavac++react')
# Out:
# favourite_programming_language:pythoncjavac++react

# %%
print('favourite_programming_language:\npython\nc\njava\nc++\nreact')
# Out:
# favourite_programming_language:
# python
# c
# java
# c++
# react

# %%
Removing whitespaces from the strings :

# %%
name = 'python'
print(name)
# Out:
# python

# %%
name2 = '  python'
print(name2)
# Out:
#   python

# %%
name3 = '      python   '
print(name3)
# Out:
#       python

# %%
name2.lstrip()
# Out:
# 'python'

# %%
name3.rstrip()
# Out:
# '      python'
