# %%
useraccount ={'username': 'codetraining','firstname': 'code', 'lastname':'training', 'dob':'01-01-2020', 'pwd': '54321'}

# %%
print(useraccount)
# Out:
# {'username': 'codetraining', 'firstname': 'code', 'lastname': 'training', 'dob': '01-01-2020', 'pwd': '54321'}

# %%
alien= {'color': 'green', 'points':5 }

# %%
print(alien)
# Out:
# {'color': 'green', 'points': 5}

# %%
print(alien['color'])
# Out:
# green

# %%
print(alien['points'])
# Out:
# 5

# %%
print(alien['5'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 print(alien['5'])
#
# KeyError: '5'

# %%
alien['start_position'] = 0
print(alien)
# Out:
# {'color': 'green', 'points': 5, 'start_position': 0}

# %%
alien['color'] = 'yellow'

# %%
print(alien)
# Out:
# {'color': 'yellow', 'points': 5, 'start_position': 0}

# %%
del alien['points']

# %%
print(alien)
# Out:
# {'color': 'yellow', 'start_position': 0}
